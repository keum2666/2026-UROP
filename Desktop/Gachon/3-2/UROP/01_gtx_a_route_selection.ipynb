# %% [markdown]
# # GTX-A 경기권 서울 진입 광역버스 후보 추출
#
# 실행 전 `.env`에 `DATA_GO_KR_SERVICE_KEY`를 설정한다. 아래 셀은 같은 폴더의 `2week.py`를 실행하며, API 응답의 실제 필드명·오류·빈 결과·pagination·캐시 상태를 출력한다.
#
# 참고: 사용자가 제공한 `15154079`는 버스 노선 API가 아니므로 TAGO `BusRouteInfoInqireService`의 지역코드, 노선번호, 노선정보, 노선별 경유정류소 endpoint를 사용한다.

# %%
# %run 2week.py
